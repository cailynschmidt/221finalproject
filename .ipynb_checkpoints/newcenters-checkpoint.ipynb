# %% [markdown]
# # Updated Cooling Center Notebook
# February 28, 2025

# %%
import pandas as pd 
import geopandas as gpd

# %%
#read into Cooling Center data downloaded from LA Ready 
centers = pd.read_csv("data/GeocodeResultsCleaned_CoolingCenters(Sheet0).csv", encoding='windows-1254')

# %%
centers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 190 entries, 0 to 189
# Data columns (total 13 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   RECORD ID NUMBER                     190 non-null    object
#  1   INPUT ADDRESS                        190 non-null    object
#  2   TIGER ADDRESS RANGE MATCH INDICATOR  190 non-null    object
#  3   TIGER MATCH TYPE                     175 non-null    object
#  4   TIGER OUTPUT ADDRESS                 190 non-null    object
#  5   LONGITUDE                            190 non-null    float64
#  6   LATITUDE                             190 non-null    float64
#  7   TIGERLINE ID                         175 non-null    float64
#  8   TIGERLINE ID SIDE                    175 non-null    object
#  9   STATE CODE                           190 non-null    int64
#  10  COUNTY CODE                          190 non-null    int64
#  11  TRACT CODE                           190 non-null    int64
#  12  BLOCK CODE                           190 non-null    int64
# dtypes: float64(3), int64(4), object(6)
# memory usage: 19.4+ KB

# %%
#identify column names
centers.columns
# Out:
# Index(['RECORD ID NUMBER', 'INPUT ADDRESS ',
#        'TIGER ADDRESS RANGE MATCH INDICATOR', 'TIGER MATCH TYPE',
#        'TIGER OUTPUT ADDRESS', 'LONGITUDE ', 'LATITUDE', 'TIGERLINE ID',
#        'TIGERLINE ID SIDE', 'STATE CODE', 'COUNTY CODE', 'TRACT CODE',
#        'BLOCK CODE'],
#       dtype='object')

# %%
#rename the longitude column, which was a following space attached to its name from the original download
centers = centers.rename(columns={'LONGITUDE ': 'LONGITUDE', 'INPUT ADDRESS ': 'Address', 'RECORD ID NUMBER' : 'Name'})

# %%
#convert column names to lowercase 
centers.columns = centers.columns.str.lower()
centers.columns
# Out:
# Index(['name', 'address', 'tiger address range match indicator',
#        'tiger match type', 'tiger output address', 'longitude', 'latitude',
#        'tigerline id', 'tigerline id side', 'state code', 'county code',
#        'tract code', 'block code'],
#       dtype='object')

# %%
#convert the state, tract and county codes to a string in order to create a FIPs string
centers[['state code', 'tract code', 'county code']] = centers[['state code', 'tract code', 'county code']].astype(str)

# %%
centers['state code']
# Out:
# 0      6
# 1      6
# 2      6
# 3      6
# 4      6
#       ..
# 185    6
# 186    6
# 187    6
# 188    6
# 189    6
# Name: state code, Length: 190, dtype: object

# %%
#create a FIPS column, which will later be used to merge with the census tract data set 
#centers['FIPS'] = '06' + '037' + centers['tract code']
centers['FIPS'] = '0' + centers['state code'] + centers['county code'] + centers['tract code']
centers['FIPS'].head()
# Out:
# 0    0637106111
# 1    0637108102
# 2    0637311000
# 3    0637541100
# 4    0637540902
# Name: FIPS, dtype: object

# %%
#split address by street, city, zip to extract city to understand which cities have higher concentrations of centers
centers[['street', 'city', 'zip']] = centers["address"].str.split(",", n=2, expand=True)
centers['city']
# Out:
# 0             Sylmar
# 1       Porter Ranch
# 2            Burbank
# 3            Compton
# 4       Los Angeles
#            ...
# 185      Los Angeles
# 186       Montebello
# 187             Bell
# 188     La Crescenta
# 189         Van Nuys
# Name: city, Length: 190, dtype: object

# %%
#strip by trailing characters on the right side of the string
centers['city'] = centers['city'].str.rstrip()

# %%
centers.columns
# Out:
# Index(['name', 'address', 'tiger address range match indicator',
#        'tiger match type', 'tiger output address', 'longitude', 'latitude',
#        'tigerline id', 'tigerline id side', 'state code', 'county code',
#        'tract code', 'block code', 'FIPS', 'street', 'city', 'zip'],
#       dtype='object')

# %%
# Indices of columns to drop
column_indices_to_drop = [2,3,4,7,8,9,10]

# Drop columns by index
centers = centers.drop(centers.columns[column_indices_to_drop], axis=1)

# %%
centers.head()
# Out:
#                                          name  \
# 0  Veteran's Memorial Community Regional Park
# 1                 Porter Ranch Branch Library
# 2                           Northwest Library
# 3                         Roy Campanella Park
# 4                         A C Bilbrew Library
#
#                                        address   longitude   latitude  \
# 0                13000 Sayre St, Sylmar, 91342 -118.417156  34.324843
# 1      11371 Tampa Avenue, Porter Ranch, 91326 -118.558526  34.276780
# 2        3323 W. Victory Blvd., Burbank, 91505 -118.347214  34.184764
# 3         14812 S Stanford Ave, Compton, 90220 -118.261095  33.898681
# 4  150 E El Segundo Blvd , Los Angeles , 90061 -118.272094  33.916366
#
#   tract code  block code        FIPS                  street           city  \
# 0     106111        2003  0637106111          13000 Sayre St         Sylmar
# 1     108102        1000  0637108102      11371 Tampa Avenue   Porter Ranch
# 2     311000        3017  0637311000   3323 W. Victory Blvd.        Burbank
# 3     541100        3001  0637541100    14812 S Stanford Ave        Compton
# 4     540902        3002  0637540902  150 E El Segundo Blvd     Los Angeles
#
#       zip
# 0   91342
# 1   91326
# 2   91505
# 3   90220
# 4   90061

# %%
#create a geometry column to create a single geographic locaiton point using the provided longitude and latitude points
centers['geometry'] = gpd.points_from_xy(centers.longitude, centers.latitude)

# %%
#convert centers into a geopandas 
centers = gpd.GeoDataFrame(centers, 
                           crs='epsg: 4326', #second parameter is the crs code
                           geometry=centers['geometry']) #thrid parameter is geometry which needs to know which long/lat points to map to
centers.head()
# Out:
#                                          name  \
# 0  Veteran's Memorial Community Regional Park
# 1                 Porter Ranch Branch Library
# 2                           Northwest Library
# 3                         Roy Campanella Park
# 4                         A C Bilbrew Library
#
#                                        address   longitude   latitude  \
# 0                13000 Sayre St, Sylmar, 91342 -118.417156  34.324843
# 1      11371 Tampa Avenue, Porter Ranch, 91326 -118.558526  34.276780
# 2        3323 W. Victory Blvd., Burbank, 91505 -118.347214  34.184764
# 3         14812 S Stanford Ave, Compton, 90220 -118.261095  33.898681
# 4  150 E El Segundo Blvd , Los Angeles , 90061 -118.272094  33.916366
#
#   tract code  block code        FIPS                  street           city  \
# 0     106111        2003  0637106111          13000 Sayre St         Sylmar
# 1     108102        1000  0637108102      11371 Tampa Avenue   Porter Ranch
# 2     311000        3017  0637311000   3323 W. Victory Blvd.        Burbank
# 3     541100        3001  0637541100    14812 S Stanford Ave        Compton
# 4     540902        3002  0637540902  150 E El Segundo Blvd     Los Angeles
#
#       zip                     geometry
# 0   91342  POINT (-118.41716 34.32484)
# 1   91326  POINT (-118.55853 34.27678)
# 2   91505  POINT (-118.34721 34.18476)
# 3   90220   POINT (-118.2611 33.89868)
# 4   90061  POINT (-118.27209 33.91637)

# %%
#check that the df is now a geopandas df 
type(centers)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
#find distance between centers by importing numpy 
from shapely.geometry import Point
import numpy as np

def avg_dist(df):
    # List of points (replace with your full dataset)
    coords = [(point.x, point.y) for point in df.geometry]
    
    # Create a GeoDataFrame
    gdf = gpd.GeoDataFrame(geometry=[Point(x, y) for x, y in coords], crs="EPSG:4326") 
    
    # Reproject to a suitable CRS (EPSG:2229 for LA County in feet, EPSG:26945 for meters)
    gdf = gdf.to_crs(epsg=2229)  # Use 26945 if you prefer meters
    
    # Compute pairwise distance matrix
    dist_matrix = gdf.geometry.apply(lambda g: gdf.distance(g))
    
    # Extract upper triangle (excluding diagonal)
    distances = dist_matrix.to_numpy()
    upper_triangle = distances[np.triu_indices(len(gdf), k=1)]
    
    # Compute average distance
    average_distance_feet = round(upper_triangle.mean(), 2)
    average_distance_miles = round((average_distance_feet / 5280), 2)
    return average_distance_miles

# %%
avg_dist_LA_County = avg_dist(centers)
print("The average distance between centers in LA county is " + str(avg_dist_LA_County) + " miles.")
# Out:
# The average distance between centers in LA county is 20.3 miles.

# %%
#look specifically at centers in the city of LA 
LA_centers = centers[centers['city'] == ' Los Angeles']

# %%
LA_centers
# Out:
#                                                   name  \
# 4                                  A C Bilbrew Library
# 5                         Col. Leon H. Washington Park
# 10                            John Muir Branch Library
# 11                     East Los Angeles Service Center
# 13                            Robertson Branch Library
# ..                                                 ...
# 169                             Malabar Branch Library
# 170                          Pico Union Branch Library
# 177  East L.A./West San Gabriel Valley Comprehensiv...
# 178  Jefferson  - Vassie D. Wright Memorial Branch ...
# 185                  West Los Angeles Regional Library
#
#                                                address   longitude   latitude  \
# 4          150 E El Segundo Blvd , Los Angeles , 90061 -118.272094  33.916366
# 5                    8908 Maie Ave, Los Angeles, 90002 -118.244150  33.953341
# 10             1005 W. 64th Street, Los Angeles, 90044 -118.292070  33.981487
# 11              133 N. Sunol Drive, Los Angeles, 90063 -118.178697  34.036756
# 13     1719 S. Robertson Boulevard, Los Angeles, 90035 -118.385683  34.048454
# ..                                                 ...         ...        ...
# 169             2801 Wabash Avenue, Los Angeles, 90033 -118.197889  34.050512
# 170        1030 S. Alvarado Street, Los Angeles, 90006 -118.280076  34.051233
# 177  5301 Whittier Blvd. 2nd Floor, Los Angeles, 90022 -118.155715  34.020561
# 178    2211 W. Jefferson Boulevard, Los Angeles, 90018 -118.319209  34.026104
# 185   11360 Santa Monica Boulevard, Los Angeles, 90025 -118.450187  34.045729
#
#     tract code  block code        FIPS                         street  \
# 4       540902        3002  0637540902         150 E El Segundo Blvd
# 5       535200        1000  0637535200                  8908 Maie Ave
# 10      237401        2001  0637237401            1005 W. 64th Street
# 11      531102        1006  0637531102             133 N. Sunol Drive
# 13      217001        1013  0637217001    1719 S. Robertson Boulevard
# ..         ...         ...         ...                            ...
# 169     203200        1005  0637203200             2801 Wabash Avenue
# 170     209520        2003  0637209520        1030 S. Alvarado Street
# 177     531701        2008  0637531701  5301 Whittier Blvd. 2nd Floor
# 178     219010        1009  0637219010    2211 W. Jefferson Boulevard
# 185     267300        3000  0637267300   11360 Santa Monica Boulevard
#
#              city     zip                     geometry
# 4     Los Angeles   90061  POINT (-118.27209 33.91637)
# 5     Los Angeles   90002  POINT (-118.24415 33.95334)
# 10    Los Angeles   90044  POINT (-118.29207 33.98149)
# 11    Los Angeles   90063   POINT (-118.1787 34.03676)
# 13    Los Angeles   90035  POINT (-118.38568 34.04845)
# ..            ...     ...                          ...
# 169   Los Angeles   90033  POINT (-118.19789 34.05051)
# 170   Los Angeles   90006  POINT (-118.28008 34.05123)
# 177   Los Angeles   90022  POINT (-118.15572 34.02056)
# 178   Los Angeles   90018   POINT (-118.31921 34.0261)
# 185   Los Angeles   90025  POINT (-118.45019 34.04573)
#
# [64 rows x 11 columns]

# %%
avg_dist_LA_City = avg_dist(LA_centers)
print("The average distance between centers in the city of LA is " + str(avg_dist_LA_City) + " miles.")
# Out:
# The average distance between centers in the city of LA is 7.49 miles.

# %%
import matplotlib.pyplot as plt
import contextily as ctx

# %%
#read into the geojson file downloaded from the US Census Reporter  
tracts = gpd.read_file("data/acs2023_5yr_B01003_14000US06037575001.geojson")

# %%
tracts.info(verbose=True, show_counts=True)
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 2499 entries, 0 to 2498
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   geoid             2499 non-null   object
#  1   name              2499 non-null   object
#  2   B01003001         2499 non-null   float64
#  3   B01003001, Error  2498 non-null   float64
#  4   geometry          2499 non-null   geometry
# dtypes: float64(2), geometry(1), object(2)
# memory usage: 97.7+ KB

# %%
tracts.info(verbose=True, show_counts=True)
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 2499 entries, 0 to 2498
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   geoid             2499 non-null   object
#  1   name              2499 non-null   object
#  2   B01003001         2499 non-null   float64
#  3   B01003001, Error  2498 non-null   float64
#  4   geometry          2499 non-null   geometry
# dtypes: float64(2), geometry(1), object(2)
# memory usage: 97.7+ KB

# %%
# trim the data to the bare minimum columns
tracts = tracts[['geoid','B01003001','geometry']]

# rename the columns
tracts.columns = ['FIPS','TotalPop','geometry']
tracts['FIPS'] = tracts['FIPS'].str.replace('14000US','') #replace 15,000 US with nothing since every row has this US identifier in FIPS 
tracts.head()
# Out:
#            FIPS   TotalPop                                           geometry
# 0  05000US06037  9848406.0  MULTIPOLYGON (((-118.6782 33.03973, -118.6756 ...
# 1   06037101110     4152.0  MULTIPOLYGON (((-118.30229 34.2587, -118.30091...
# 2   06037101122     4198.0  MULTIPOLYGON (((-118.30334 34.27371, -118.3033...
# 3   06037101220     3434.0  MULTIPOLYGON (((-118.28592 34.25404, -118.2859...
# 4   06037101221     3931.0  MULTIPOLYGON (((-118.29792 34.25597, -118.2969...

# %%
# delete first row which is for the entire city of LA
tracts.drop(tracts.head(1).index,inplace=True) #1 is the first value of the tail and index resets the index

# %%
#subset data with pop less than 100 out of df 
tracts = tracts[tracts['TotalPop']>100]

# %%
tracts.shape
# Out:
# (2468, 3)

# %%
tracts = tracts.to_crs(epsg=3857) #keep consistent projection

# %%
fig,ax = plt.subplots(figsize=(15,15))
tracts.plot(ax=ax,zorder=10,alpha=0.5) #z is lowest layer on the plot, alpha is transparency
tracts.boundary.plot(ax=ax,color='black',zorder=20,lw=0.2)
# Out:
# <Axes: >

# %%
centers = centers.to_crs(epsg=3857)

# %%
# get the bounding box coordinates for the centers data
minx, miny, maxx, maxy = centers.geometry.total_bounds
print(minx)
print(maxx)
print(miny)
print(maxy)
# Out:
# -13224683.415738665
# -13104123.360806333
# 3993459.184591898
# 4123719.9021027423

# %%
fig, ax = plt.subplots(figsize=(20, 20))

# plot tracts
tracts.plot(ax=ax, # this puts it in the ax plot
        color='lightgray', 
        edgecolor='white',
        alpha=0.5)

# add centers to the plot 
centers.plot(ax=ax, #plot it here in ax in the empty sublot 
        marker='X', #instead of default marker, mark with an X
        markersize=20,
        color='green')

# turn the axes off
ax.axis('off')

ax.set_title('Cooling Centers Across LA County 2024')

# use the bounding box coordinates to set the x and y limits
ax.set_xlim(minx - 1000, maxx + 1000) # added/substracted value is to give some margin around total bounds
ax.set_ylim(miny - 1000, maxy + 1000)

# add a basemap
ctx.add_basemap(ax,source=ctx.providers.CartoDB.Positron)

# %% [markdown]
# # Average number of centers per census tract
# Before merging the dataset, find the average number of centers per census tract.

# %%
totalTracts = len(tracts.FIPS)
totalCenters = len(centers["name"])

print("There are " + str(totalCenters) + " cooling centers across LA County.")
# Out:
# There are 190 cooling centers across LA County.

# %%
totalTracts
# Out:
# 2468

# %%
centerPerTract= totalCenters / totalTracts
centerPerTract
# Out:
# 0.07698541329011345

# %%
centerPerTractPercent = round(centerPerTract * 100, 2)

# %%
print("" + str(centerPerTractPercent) + " of census tracts in LA County have a cooling center.")
# Out:
# 7.7 of census tracts in LA County have a cooling center.

# %%
centers.shape
# Out:
# (190, 11)

# %%
tracts.shape
# Out:
# (2468, 3)

# %%
centers.columns
# Out:
# Index(['name', 'address', 'longitude', 'latitude', 'tract code', 'block code',
#        'FIPS', 'street', 'city', 'zip', 'geometry'],
#       dtype='object')

# %%
# Indices of columns to drop
column_indices_to_drop = [6]
centers = centers.drop(centers.columns[column_indices_to_drop], axis=1)

# %%
join = gpd.sjoin(tracts, centers, how='left')

# %%
join.shape
# Out:
# (2479, 13)

# %%
join.head()
# Out:
#           FIPS  TotalPop                                           geometry  \
# 1  06037101110    4152.0  MULTIPOLYGON (((-13169350.794 4063591.834, -13...
# 2  06037101122    4198.0  MULTIPOLYGON (((-13169467.902 4065613.937, -13...
# 3  06037101220    3434.0  MULTIPOLYGON (((-13167528.828 4062965.287, -13...
# 4  06037101221    3931.0  MULTIPOLYGON (((-13168864.105 4063224.413, -13...
# 5  06037101222    2572.0  MULTIPOLYGON (((-13168465.581 4062734.852, -13...
#
#    index_right                              name  \
# 1         17.0  Sunland - Tujunga Branch Library
# 2          NaN                               NaN
# 3          NaN                               NaN
# 4          NaN                               NaN
# 5          NaN                               NaN
#
#                                    address   longitude   latitude tract code  \
# 1  7771 Foothill Boulevard, Tujunga, 91042 -118.301705  34.258222     101110
# 2                                      NaN         NaN        NaN        NaN
# 3                                      NaN         NaN        NaN        NaN
# 4                                      NaN         NaN        NaN        NaN
# 5                                      NaN         NaN        NaN        NaN
#
#    block code                   street      city     zip
# 1      2007.0  7771 Foothill Boulevard   Tujunga   91042
# 2         NaN                      NaN       NaN     NaN
# 3         NaN                      NaN       NaN     NaN
# 4         NaN                      NaN       NaN     NaN
# 5         NaN                      NaN       NaN     NaN

# %%
centers_by_tract = join.FIPS.value_counts(join.name).rename_axis('FIPS').reset_index(name='centers_count').sort_values(by='centers_count', ascending=False)
centers_by_tract
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_5872/2282715117.py in ?()
# ----> 1 centers_by_tract = join.FIPS.value_counts(join.name).rename_axis('FIPS').reset_index(name='centers_count').sort_values(by='centers_count', ascending=False)
#       2 centers_by_tract
#
# /opt/conda/lib/python3.11/site-packages/pandas/core/base.py in ?(self, normalize, sort, ascending, bins, dropna)
#    1006         4.0    1
#    1007         NaN    1
#    1008         Name: count, dtype: int64
#    1009         """
# -> 1010         return algorithms.value_counts_internal(
#    1011             self,
#    1012             sort=sort,
#    1013             ascending=ascending,
#
# /opt/conda/lib/python3.11/site-packages/pandas/core/algorithms.py in ?(values, sort, ascending, normalize, bins, dropna)
#     872         Series,
#     873     )
#     874
#     875     index_name = getattr(values, "name", None)
# --> 876     name = "proportion" if normalize else "count"
#     877
#     878     if bins is not None:
#     879         from pandas.core.reshape.tile import cut
#
# /opt/conda/lib/python3.11/site-packages/pandas/core/generic.py in ?(self)
#    1575     @final
#    1576     def __nonzero__(self) -> NoReturn:
# -> 1577         raise ValueError(
#    1578             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1579             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1580         )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
tract_morethan1 = centers_by_tract[centers_by_tract['centers_count'] >= 2]
print("There are " + str(len(tract_morethan1)) + " census tracts with 2 or more centers.")
# Out:
# There are 11 census tracts with 2 or more centers.

# %%
#print census tract code
for x in tract_morethan1['FIPS']:
    print(x[4:])
# Out:
# 104124
# 106111
# 228710
# 535200
# 540902
# 800335
# 900806
# 431004
# 430502
# 504200
# 296600

# %%
tracts_just1 = centers_by_tract[centers_by_tract['centers_count'] == 1]
print("There are " + str(len(tracts_just1)) + " census tracts with only 1 centers.")
# Out:
# There are 168 census tracts with only 1 centers.

# %%
centers_by_city = join.value_counts('city').reset_index(name='count').sort_values(by='count', ascending=False)
city_morethan1 = centers_by_city[centers_by_city['count'] >= 2]
city_morethan1
# Out:
#                  city  count
# 0         Los Angeles     64
# 1           Inglewood      6
# 2            Torrance      6
# 3              Sylmar      4
# 4             Compton      4
# 5            Whittier      4
# 6           Lancaster      3
# 7              Pomona      3
# 8            Altadena      3
# 9    Hacienda Heights      2
# 10     Woodland Hills      2
# 11          San Pedro      2
# 12    North Hollywood      2
# 13            Norwalk      2
# 14          La Puente      2
# 15           Monrovia      2
# 16           Lakewood      2
# 17        Quartz Hill      2
# 18        Culver City      2
# 19          Claremont      2
# 20            Burbank      2
# 21       Baldwin Park      2
# 22   Santa Fe Springs      2
# 23       Sierra Madre      2
# 24       La Crescenta      2

# %%
ax = city_morethan1.head(10).plot.barh(x='city',
                                   y='count',
                                   title= 'Top 10 Cities with the Highest Count of Cooling Centers LA County 2024',
                                   color = '#a8ddb5')

ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))

ax.figure.savefig('top_10_cities_centers.png', bbox_inches='tight')

# %%
centers_by_tract['centers_count'].describe()
# Out:
# count    179.000000
# mean       1.061453
# std        0.240832
# min        1.000000
# 25%        1.000000
# 50%        1.000000
# 75%        1.000000
# max        2.000000
# Name: centers_count, dtype: float64

# %%
join.drop(join['FIPS_right'], axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[88], line 1
# ----> 1 join.drop(join['FIPS_right'], axis=1)
#
# File /opt/conda/lib/python3.11/site-packages/pandas/core/frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
#    5588         errors=errors,
#    5589     )
#
# File /opt/conda/lib/python3.11/site-packages/pandas/core/generic.py:4788, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786 for axis, labels in axes.items():
#    4787     if labels is not None:
# -> 4788         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4790 if inplace:
#    4791     self._update_inplace(obj)
#
# File /opt/conda/lib/python3.11/site-packages/pandas/core/generic.py:4830, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4828         new_axis = axis.drop(labels, level=level, errors=errors)
#    4829     else:
# -> 4830         new_axis = axis.drop(labels, errors=errors)
#    4831     indexer = axis.get_indexer(new_axis)
#    4833 # Case for non-unique axis
#    4834 else:
#
# File /opt/conda/lib/python3.11/site-packages/pandas/core/indexes/base.py:7070, in Index.drop(self, labels, errors)
#    7068 if mask.any():
#    7069     if errors != "ignore":
# -> 7070         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7071     indexer = indexer[~mask]
#    7072 return self.delete(indexer)
#
# KeyError: "['0637101110', nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, '0637104124', '0637104124', nan, nan, nan, nan, nan, nan, nan, nan, '0637104404', nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, '0637106111', '0637106111', nan, nan, nan, nan, nan, nan, nan, nan, nan, '0637106520', nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, '0637108102', nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, '0637111402', nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, '0637113323', nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, '0637117303', nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, '0637120104', nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, '0637122121', nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, '0637123301', nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, '0637125200', nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, '0637128210', nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, '0637132502', nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, '0637134521', nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, '0637135202', nan, nan, nan, nan, nan, nan, nan, nan, nan, '0637137401', nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, '0637139502', nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, '0637141201', nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, '0637143401', nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, '0637181400', nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, '0637183620', nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, '0637188300', '0637189101', nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, '0637189906', nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, '0637190701', nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, '0637191301', nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, '0637191902', nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, '0637195100', nan, nan, nan, nan, nan, '0637195600', nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, '0637199201', nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, '0637201501', nan, nan, nan, nan, nan, nan, '0637203200', nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, '0637204810', nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, '0637207102', nan, nan, nan, nan, '0637207306', nan, nan, nan, nan, nan, nan, '0637207712', nan, nan, nan, '0637208002', nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, '0637209520', nan, nan, nan, nan, nan, nan, '0637211123', nan, nan, nan, nan, nan, nan, nan, '0637211500', nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, '0637212502', nan, nan, nan, '0637212702', nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, '0637214501', nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,  ...

# %%
#merged = tracts.merge(centers_by_tract,on="FIPS") 
merged=join.merge(centers_by_tract,on='FIPS_left')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_5872/3037627708.py in ?()
#       1 #merged = tracts.merge(centers_by_tract,on="FIPS")
# ----> 2 merged=join.merge(centers_by_tract,on='FIPS_left')
#
# /opt/conda/lib/python3.11/site-packages/pandas/core/frame.py in ?(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#   10828         validate: MergeValidate | None = None,
#   10829     ) -> DataFrame:
#   10830         from pandas.core.reshape.merge import merge
#   10831
# > 10832         return merge(
#   10833             self,
#   10834             right,
#   10835             how=how,
#
# /opt/conda/lib/python3.11/site-packages/pandas/core/reshape/merge.py in ?(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     166             validate=validate,
#     167             copy=copy,
#     168         )
#     169     else:
# --> 170         op = _MergeOperation(
#     171             left_df,
#     172             right_df,
#     173             how=how,
#
# /opt/conda/lib/python3.11/site-packages/pandas/core/reshape/merge.py in ?(self, left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, indicator, validate)
#     790             self.right_join_keys,
#     791             self.join_names,
#     792             left_drop,
#     793             right_drop,
# --> 794         ) = self._get_merge_keys()
#     795
#     796         if left_drop:
#     797             self.left = self.left._drop_labels_or_levels(left_drop)
#
# /opt/conda/lib/python3.11/site-packages/pandas/core/reshape/merge.py in ?(self)
#    1293                         # Then we're either Hashable or a wrong-length arraylike,
#    1294                         #  the latter of which will raise
#    1295                         rk = cast(Hashable, rk)
#    1296                         if rk is not None:
# -> 1297                             right_keys.append(right._get_label_or_level_values(rk))
#    1298                         else:
#    1299                             # work-around for merge_asof(right_index=True)
#    1300                             right_keys.append(right.index._values)
#
# /opt/conda/lib/python3.11/site-packages/pandas/core/generic.py in ?(self, key, axis)
#    1907             values = self.xs(key, axis=other_axes[0])._values
#    1908         elif self._is_level_reference(key, axis=axis):
#    1909             values = self.axes[axis].get_level_values(key)._values
#    1910         else:
# -> 1911             raise KeyError(key)
#    1912
#    1913         # Check for duplicates
#    1914         if values.ndim > 1:
#
# KeyError: 'FIPS_left'

# %%
#check merge
merged.head()
# Out:
# Empty GeoDataFrame
# Columns: [FIPS, TotalPop, geometry, centers_count]
# Index: []

# %%
merged.columns
# Out:
# Index(['name', 'address', 'longitude', 'latitude', 'tract code', 'block code',
#        'FIPS', 'street', 'city', 'zip', 'geometry_x', 'CT20', 'geometry_y'],
#       dtype='object')

# %%
merged.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 190 entries, 0 to 189
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        190 non-null    object
#  1   address     190 non-null    object
#  2   longitude   190 non-null    float64
#  3   latitude    190 non-null    float64
#  4   tract code  190 non-null    object
#  5   block code  190 non-null    int64
#  6   FIPS        190 non-null    object
#  7   street      190 non-null    object
#  8   city        190 non-null    object
#  9   zip         190 non-null    object
#  10  geometry_x  190 non-null    geometry
#  11  CT20        190 non-null    object
#  12  geometry_y  190 non-null    geometry
# dtypes: float64(2), geometry(2), int64(1), object(8)
# memory usage: 19.4+ KB

# %%
merged.geometry_x
# Out:
# 0      POINT (-118.41716 34.32484)
# 1      POINT (-118.55853 34.27678)
# 2      POINT (-118.34721 34.18476)
# 3       POINT (-118.2611 33.89868)
# 4      POINT (-118.27209 33.91637)
#                   ...
# 185    POINT (-118.45019 34.04573)
# 186    POINT (-118.09446 34.04358)
# 187    POINT (-118.16868 33.99089)
# 188     POINT (-118.25563 34.2241)
# 189    POINT (-118.44634 34.18389)
# Name: geometry_x, Length: 190, dtype: geometry

# %%
import folium

# %%
m = folium.Map(location=[34.2,-118.2], 
               zoom_start = 9,
               tiles='CartoDB positron', 
               attribution='CartoDB')

# plot chorpleth over the base map
folium.Choropleth(
                  geo_data=centers, 
                  data= centers_by_tract, 
                  columns=["tract code", "count"],
                  key_on='feature.properties.FIPS',
                  fill_color='BuPu',
                  line_weight=0.1, 
                  fill_opacity=0.8,
                  line_opacity=0.2, # line opacity (of the border)
                  legend_name='Cooling Centers across LA County',
                highlight=True).add_to(m)    # name on the legend color bar

folium.LayerControl(position = 'topright', collapsed=True, autoZIndex=True).add_to(m) #need capital T for true or capital F for False

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_67a507265563fc7116e2f681eecad359 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_67a507265563fc7116e2f681eecad359&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_67a507265563fc7116e2f681eecad359 = L.map(
#                 &quot;map_67a507265563fc7116e2f681eecad359&quot;,
#                 {
#                     center: [34.2, -118.2],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 9,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
#   &quot;attribution&quot;: &quot;CartoDB&quot;,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c6788a75b70eecd7439baf71c1ae7f0e = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c6788a75b70eecd7439baf71c1ae7f0e.addTo(map_67a507265563fc7116e2f681eecad359);
#
#
#             var choropleth_8c761300154f287138eccb430cbdebda = L.featureGroup(
#                 {
# }
#             );
#
#
#         function geo_json_2239999920d3bdb19cfb4a0c75a9aaae_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 0.8, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 0.1};
#             }
#         }
#         function geo_json_2239999920d3bdb19cfb4a0c75a9aaae_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 1.0, &quot;weight&quot;: 2.1};
#             }
#         }
#
#         function geo_json_2239999920d3bdb19cfb4a0c75a9aaae_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_2239999920d3bdb19cfb4a0c75a9aaae.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_2239999920d3bdb19cfb4a0c75a9aaae_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_2239999920d3bdb19cfb4a0c75a9aaae = L.geoJson(null, {
#                 onEachFeature: geo_json_2239999920d3bdb19cfb4a0c75a9aaae_onEachFeature,
#
#                 style: geo_json_2239999920d3bdb19cfb4a0c75a9aaae_styler,
#             ...{
# }
#         });
#
#         function geo_json_2239999920d3bdb19cfb4a0c75a9aaae_add (data) {
#             geo_json_2239999920d3bdb19cfb4a0c75a9aaae
#                 .addData(data);
#         }
#             geo_json_2239999920d3bdb19cfb4a0c75a9aaae_add({&quot;bbox&quot;: [-118.7993524, 33.73638145, -117.716343, 34.70393777], &quot;features&quot;: [{&quot;bbox&quot;: [-118.4171561, 34.32484314, -118.4171561, 34.32484314], &quot;geometry&quot;: {&quot;coordinates&quot;: [-118.4171561, 34.32484314], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;FIPS&quot;: &quot;06037106111&quot;, &quot;address&quot;: &quot;13000 Sayre St, Sylmar, 91342&quot;, &quot;block code&quot;: 2003, &quot;city&quot;: &quot; Sylmar&quot;, &quot;latitude&quot;: 34.32484314, &quot;longitude&quot;: -118.4171561, &quot;name&quot;: &quot;Veteran\u0027s Memorial Community Regional Park&quot;, &quot;street&quot;: &quot;13000 Sayre St&quot;, &quot;tract code&quot;: &quot;106111&quot;, &quot;zip&quot;: &quot; 91342&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [-118.5585263, 34.27677975, -118.5585263, 34.27677975], &quot;geometry&quot;: {&quot;coordinates&quot;: [-118.5585263, 34.27677975], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;1&quot;, &quot;properties&quot;: {&quot;FIPS&quot;: &quot;06037108102&quot;, &quot;address&quot;: &quot;11371 Tampa Avenue, Porter Ranch, 91326&quot;, &quot;block code&quot;: 1000, &quot;city&quot;: &quot; Porter Ranch&quot;, &quot;latitude&quot;: 34.27677975, &quot;longitude&quot;: -118.5585263, &quot;name&quot;: &quot;Porter Ranch Branch Library&quot;, &quot;street&quot;: &quot;11371 Tampa Avenue&quot;, &quot;tract code&quot;: &quot;108102&quot;, &quot;zip&quot;: &quot; 91326&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [-118.3472137, 34.18476377, -118.3472137, 34.18476377], &quot;geometry&quot;: {&quot;coordinates&quot;: [-118.3472137, 34.18476377], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;2&quot;, &quot;properties&quot;: {&quot;FIPS&quot;: &quot;06037311000&quot;, &quot;address&quot;: &quot;
